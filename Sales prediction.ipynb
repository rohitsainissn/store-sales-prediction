# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('Train.csv')
# pd.set_option('display.max_columns', None)
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dy = pd.read_csv('Test.csv')
df = pd.concat([df, dy])
df.reset_index(drop=True, inplace=True)
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df.describe(include='all')
# Out:
#        Item_Identifier   Item_Weight Item_Fat_Content  Item_Visibility  \
# count            14204  11765.000000            14204     14204.000000
# unique            1559           NaN                5              NaN
# top              FDU15           NaN          Low Fat              NaN
# freq                10           NaN             8485              NaN
# mean               NaN     12.792854              NaN         0.065953
# std                NaN      4.652502              NaN         0.051459
# min                NaN      4.555000              NaN         0.000000
# 25%                NaN      8.710000              NaN         0.027036
# 50%                NaN     12.600000              NaN         0.054021
# 75%                NaN     16.750000              NaN         0.094037
# max                NaN     21.350000              NaN         0.328391
#
#                     Item_Type      Item_MRP Outlet_Identifier  \
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df.Item_Fat_Content.value_counts()
# Out:
# Low Fat    8485
# Regular    4824
# LF          522
# reg         195
# low fat     178
# Name: Item_Fat_Content, dtype: int64

# %%
df.Item_Fat_Content = df.Item_Fat_Content.replace(['Low Fat','LF','low fat','Regular', 'reg'],[0,0,0,1,1])

# %%
df.Outlet_Size.value_counts()
# Out:
# Medium    4655
# Small     3980
# High      1553
# Name: Outlet_Size, dtype: int64

# %%
df.Outlet_Size = df.Outlet_Size.replace(['Small','Medium','High'],[1,2,3])

# %%
df.Outlet_Location_Type.value_counts()
# Out:
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64

# %%
df.Outlet_Location_Type = df.Outlet_Location_Type.replace(['Tier 1','Tier 2','Tier 3'],[1,2,3])

# %%
df.Outlet_Type.value_counts()
# Out:
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# Supermarket Type2    1546
# Name: Outlet_Type, dtype: int64

# %%
df.Outlet_Type = df.Outlet_Type.replace(['Grocery Store','Supermarket Type1','Supermarket Type2','Supermarket Type3'],[1,2,3,4])

# %%
df = pd.get_dummies(df, columns=['Item_Type'], drop_first=True)
df = pd.get_dummies(df, columns=['Item_Identifier'], drop_first=True)
df = pd.get_dummies(df, columns=['Outlet_Identifier'], drop_first=True)

# %%
df.Item_Outlet_Sales.isnull().sum()
# Out:
# 5681

# %%
x = df.drop('Item_Outlet_Sales',axis =1)
y = df.Item_Outlet_Sales

# %%
x_train = x.iloc[:8523]
x_test = x.iloc[8523:]
y_train = y[:8523]
y_test = y[8523:]

# %%
y_train.tail()
# Out:
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, dtype: float64

# %%
y_test.head()
# Out:
# 8523   NaN
# 8524   NaN
# 8525   NaN
# 8526   NaN
# 8527   NaN
# Name: Item_Outlet_Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_cv, y_train, y_cv = train_test_split(x_train, y_train, test_size=0.33, random_state=42)

# %%
x_cv['Item_Weight_Missing'] = x_cv['Item_Weight'].isnull().astype(int)
mean_item_weight =x_cv['Item_Weight'].mean()
x_cv['Item_Weight'].fillna(mean_item_weight, inplace=True)
x_cv['Outlet_Size_Missing'] = x_cv['Outlet_Size'].isnull().astype(int)
x_cv['Outlet_Size'].fillna(2, inplace=True)

# %%
x_train['Item_Weight_Missing'] = x_train['Item_Weight'].isnull().astype(int)
mean_item_weight =x_train['Item_Weight'].mean()
x_train['Item_Weight'].fillna(mean_item_weight, inplace=True)
x_train['Outlet_Size_Missing'] = x_train['Outlet_Size'].isnull().astype(int)
x_train['Outlet_Size'].fillna(2, inplace=True)

# %%
x_test['Item_Weight_Missing'] = x_test['Item_Weight'].isnull().astype(int)
mean_item_weight =x_test['Item_Weight'].mean()
x_test['Item_Weight'].fillna(mean_item_weight, inplace=True)
x_test['Outlet_Size_Missing'] = x_test['Outlet_Size'].isnull().astype(int)
x_test['Outlet_Size'].fillna(2, inplace=True)
# Out:
# /var/folders/1x/5gvchf9n2rggz1tvjvsdmq300000gn/T/ipykernel_7200/2286674016.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['Item_Weight_Missing'] = x_test['Item_Weight'].isnull().astype(int)
# /var/folders/1x/5gvchf9n2rggz1tvjvsdmq300000gn/T/ipykernel_7200/2286674016.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['Item_Weight'].fillna(mean_item_weight, inplace=True)
# /var/folders/1x/5gvchf9n2rggz1tvjvsdmq300000gn/T/ipykernel_7200/2286674016.py:4: SettingWithCopyWarning:
# ...

# %%
x_test
# Out:
#        Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 8523     20.750000                 0         0.007565  107.8622
# 8524      8.300000                 1         0.038428   87.3198
# 8525     14.600000                 0         0.099575  241.7538
# 8526      7.315000                 0         0.015388  155.0340
# 8527     12.695633                 1         0.118599  234.2300
# ...            ...               ...              ...       ...
# 14199    10.500000                 1         0.013496  141.3154
# 14200     7.600000                 1         0.142991  169.1448
# 14201    10.000000                 0         0.073529  118.7440
# 14202    15.300000                 1         0.000000  214.6218
# 14203     9.500000                 1         0.104720   79.7960
#
#        Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 8523                        1999          2.0                     1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_array = scaler.fit_transform(x_train)
x_train = pd.DataFrame(x_array, index=x_train.index, columns=x_train.columns)
x_array = scaler.transform(x_test)
x_test = pd.DataFrame(x_array, index=x_test.index, columns=x_test.columns)
x_array = scaler.transform(x_cv)
x_cv = pd.DataFrame(x_array, index=x_cv.index, columns=x_test.columns)

# %%
import math
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from tensorflow.keras.callbacks import  EarlyStopping

learning_rate = 0.01
early_stopping_callback = EarlyStopping(monitor='mean_squared_logarithmic_error', patience=6)
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(16, kernel_initializer='he_normal', activation='relu'),
    Dropout(.3),
    Dense(32, kernel_initializer='he_normal', activation='relu'),
    Dropout(.3),
    Dense(16, kernel_initializer='he_normal', activation='relu'),

    Dense(64, kernel_initializer='he_normal', activation='relu'),
    Dropout(.3), 
    Dense(32, kernel_initializer='he_normal', activation='relu'),
      
    Dense(1, kernel_initializer='he_normal', activation='linear')

  ])
    
  return model
# build the model
model = build_model_using_sequential()
# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=msle
)
# train the model
history = model.fit(
    x_train.values, 
    y_train.values, 
    epochs=200, 
    batch_size=64,
    validation_freq=.2,
    callbacks=[early_stopping_callback]
)
# Out:
# 2023-10-08 20:59:35.204240: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 90/90 [==============================] - 2s 3ms/step - loss: 5.0885 - mean_squared_logarithmic_error: 5.0509
# Epoch 2/200
# 90/90 [==============================] - 0s 3ms/step - loss: 0.7366 - mean_squared_logarithmic_error: 0.7331
# Epoch 3/200
# 90/90 [==============================] - 0s 3ms/step - loss: 0.4647 - mean_squared_logarithmic_error: 0.4645
# Epoch 4/200
# 90/90 [==============================] - 0s 3ms/step - loss: 0.3623 - mean_squared_logarithmic_error: 0.3634
# Epoch 5/200
# 90/90 [==============================] - 0s 3ms/step - loss: 0.3305 - mean_squared_logarithmic_error: 0.3294
# Epoch 6/200
# ...

# %%
y_pred = model.predict(x_cv)
y_pred
# Out:
# 88/88 [==============================] - 0s 2ms/step
# array([[ 877.5992 ],
#        [ 919.33875],
#        [ 555.16425],
#        ...,
#        [1952.3661 ],
#        [1684.0933 ],
#        [ 707.3555 ]], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2_score(y_cv, y_pred)
# Out:
# 0.33223712957085627

# %%
import xgboost as xg
from sklearn.model_selection import GridSearchCV

# Create the regressor object
model = xg.XGBRegressor()

# Define the parameter grid for grid search
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [100, 500, 1000],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5,n_jobs = -1)

# Fit the grid search to the training data
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
# Get the best model from grid search
best_model = grid_search.best_estimator_

# Predict on the test set using the best model
y_pred = best_model.predict(x_cv)

# Calculate the variance score (R^2) of the best model on the test set
score = best_model.score(x_cv, y_cv)
print('Variance score (R^2): {}'.format(score))

# Get the best hyperparameters from grid search
best_params = grid_search.best_params_
# Out:
# Variance score (R^2): 0.6039355363235436

# %%
best_params
# Out:
# {'colsample_bytree': 0.8,
#  'learning_rate': 0.01,
#  'max_depth': 3,
#  'n_estimators': 500,
#  'subsample': 0.8}

# %%
y_pred = best_model.predict(x_test)
y_pred
# Out:
# array([1683.639  , 1385.2598 ,  776.74994, ..., 1958.7646 , 3475.5562 ,
#        1303.4954 ], dtype=float32)

# %%
# from sklearn.ensemble import AdaBoostRegressor
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.model_selection import GridSearchCV

# # Create the base estimator
# base_estimator = DecisionTreeRegressor()

# # Create the AdaBoostRegressor
# model = AdaBoostRegressor(base_estimator=base_estimator, random_state=1)

# # Define the parameter grid for grid search
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'learning_rate': [0.001, 0.01, 0.1]
# }

# # Create the GridSearchCV object
# grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs =-1)

# # Fit the grid search to the training data
# grid_search.fit(x_train, y_train)

# # Get the best model from grid search
# best_model = grid_search.best_estimator_

# # Predict on the test set using the best model
# y_pred = best_model.predict(x_cv)

# # Calculate the variance score (R^2) of the best model on the test set
# score = best_model.score(x_cv, y_cv)
# print('Variance score (R^2): {}'.format(score))

# # Get the best hyperparameters from grid search
# best_params = grid_search.best_params_
# print('Best hyperparameters:', best_params)
# Out:
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

# Create a regressor object
model = DecisionTreeRegressor(random_state=0)

# Define the parameter grid for grid search
param_grid = {
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=model,n_jobs =-1, param_grid=param_grid, cv=5)

# Fit the grid search to the training data
grid_search.fit(x_train, y_train)

# Get the best model from grid search
best_model = grid_search.best_estimator_

# Predict on the test set using the best model
y_pred = best_model.predict(x_cv)

# Calculate the variance score (R^2) of the best model on the test set
score = best_model.score(x_cv, y_cv)
print('Variance score (R^2): {}'.format(score))

# Get the best hyperparameters from grid search
best_params = grid_search.best_params_
print('Best hyperparameters:', best_params)
# Out:
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# ...

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, r2_score

# Create the ExtraTreesRegressor model
model = ExtraTreesRegressor()

# Define the hyperparameters you want to tune
parameters = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 4, 6],
}

# Create a scorer using r2_score
scorer = make_scorer(r2_score)

# Perform grid search with cross-validation
grid_search = GridSearchCV(model, parameters, n_jobs = -1,scoring=scorer, cv=5)
grid_search.fit(x_train, y_train)

# Get the best model and its score
best_model = grid_search.best_estimator_
best_score = grid_search.best_score_

# Make predictions using the best model
y_pred9 = best_model.predict(x_cv)
score = best_model.score(x_cv, y_cv)
print('Variance score (R^2): {}'.format(score))

print('Best hyperparameters:', grid_search.best_params_)
print('Best variance score (r2):', best_score)
# Out:
# Variance score (R^2): 0.6026233752763761
# Best hyperparameters: {'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 300}
# Best variance score (r2): 0.5940466817495148

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, r2_score

# Create the SGDRegressor model
model = SGDRegressor()

# Define the hyperparameters you want to tune
parameters = {
    'alpha': [0.0001, 0.001, 0.01, 0.1,1],
    'l1_ratio': [0.2, 0.4, 0.6, 0.8],
    'max_iter': [1000, 2000, 3000]
}

# Create a scorer using r2_score
scorer = make_scorer(r2_score)

# Perform grid search with cross-validation
grid_search = GridSearchCV(model, parameters,n_jobs = -1 ,scoring=scorer, cv=5)
grid_search.fit(x_train, y_train)

# Get the best model and its score
best_model = grid_search.best_estimator_
best_score = grid_search.best_score_

# Make predictions using the best model
y_pred2 = best_model.predict(x_cv)
score = best_model.score(x_cv, y_cv)
print('Variance score (R^2): {}'.format(score))

print('Best hyperparameters:', grid_search.best_params_)
print('Best variance score (r2):', best_score)
# Out:
# Variance score (R^2): 0.5606288063990739
# Best hyperparameters: {'alpha': 0.001, 'l1_ratio': 0.8, 'max_iter': 2000}
# Best variance score (r2): 0.5488466928821163

# %%
from sklearn.linear_model import LinearRegression,Lasso
from sklearn import datasets, metrics
# this model is corrected by lasso regression
a = [0,.01,.1,1.5,10,12,15,20,25,28,30,40,50,75,100,200,500]
for i in a:
    model = Lasso(alpha=i)
    model.fit(x_train, y_train)
    y_pred1 = model.predict(x_cv)
    print(f'{i}  Variance score or r_sq: {model.score(x_cv, y_cv)}')
# Out:
# /var/folders/1x/5gvchf9n2rggz1tvjvsdmq300000gn/T/ipykernel_7200/1216882087.py:7: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   model.fit(x_train, y_train)
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /Users/prayer/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.725e+09, tolerance: 1.692e+06 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# ...
